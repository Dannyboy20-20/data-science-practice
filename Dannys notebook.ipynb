# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
#  **Danny Mahmoudi**
# Desired occupation: Doctor

# %% [markdown]
#  *I am interested in Data Science as a way of furthering my skills as a researcher as well as improving my employability as a scientist. It can be difficult to market my skills as a physicist, but Data Science will surely help!*

# %% [markdown]
# ### My code is supposed to print "physics > engineering"

# %%
print("Physics>engineering")
# Out:
# Physics>engineering

# %% [markdown]
# ***
# -  item1
# -  item2
# -  item 3 of the bulleted list
# ![il_570xN.3594068092_pk0e.webp](attachment:il_570xN.3594068092_pk0e.webp)
